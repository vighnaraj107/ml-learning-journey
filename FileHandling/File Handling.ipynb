# %% [markdown]
# **Reading a file**

# %%
f=open('myfiletext.txt','r')

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='myfiletext.txt' mode='r' encoding='cp1252'>

# %%
text=f.read()
print(text)
f.close()
# Out:
# hello im vighnaraj

# %% [markdown]
# **Writing a file**

# %%
f=open('myfiletext.txt','w')
f.write('Hello world')
print(f)
f.close()
# Out:
# <_io.TextIOWrapper name='myfiletext.txt' mode='w' encoding='cp1252'>

# %%
with open('myfiletext.txt','w') as f:
    f.write('hey i like you ')
